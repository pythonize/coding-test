# %% [markdown]
#  11. 자연수 뒤집어 배열로 만들기(241023) - 오답

# %% [markdown]
# 문제 설명
#
# 자연수 n을 뒤집어 각 자리 숫자를 원소로 가지는 배열 형태로 리턴해주세요. 예를들어 n이 12345이면 [5,4,3,2,1]을 리턴합니다.
#
# 제한 조건
#
# n은 10,000,000,000이하인 자연수입니다.
#
# 입출력 예
#
# n	return
#
# 12345	[5,4,3,2,1]

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(n):
    for i in range(len(str(n))):
        answer[i] = answer[-i]
    return answer

# %%
solution(12345)

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(n):
    # n을 문자열로 변환한 후 거꾸로 뒤집고 다시 정수로 변환
    return int(str(n)[::-1])

# 예시 실행
print(solution(1234))  # 출력: 4321
# Out:
# 4321

# %%
solution(1234)
# Out:
# 4321

# %% [markdown]
#  12. 정수 내림차순으로 배치하기 - 오답

# %% [markdown]
#  문제 설명
#
# 함수 solution은 정수 n을 매개변수로 입력받습니다. n의 각 자릿수를 큰것부터 작은 순으로 정렬한 새로운 정수를 리턴해주세요. 예를들어 n이 118372면 873211을 리턴하면 됩니다.
#
# 제한 조건
#
# n은 1이상 8000000000 이하인 자연수입니다.
#
# 입출력 예
#
# n	return
#
# 118372	873211

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(n):
    str_n = list(str(n))
    str_n.sort()
    answer = str_n.reverse()
    return answer

# %%
solution(88214515)

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(n):
    # 숫자를 문자열로 변환한 후 리스트로 만듦
    str_n = list(str(n))

    # 리스트를 정렬한 후 뒤집기
    str_n.sort(reverse=True)

    # 리스트를 문자열로 합치고 정수로 변환
    answer = int(''.join(str_n))

    return answer

# 예시 실행
print(solution(88214515))  # 출력: 88554211
# Out:
# 88554211

# %%
solution(88214515)
# Out:
# 88554211

# %% [markdown]
#  13. 자연수 뒤집어 배열로 만들기(241030)

# %%
# 문제 설명
# 자연수 n을 뒤집어 각 자리 숫자를 원소로 가지는 배열 형태로 리턴해주세요.
# 예를들어 n이 12345이면 [5,4,3,2,1]을 리턴합니다.

# 제한 조건
# n은 10,000,000,000이하인 자연수입니다.

# 입출력 예
# n	return
# 12345	[5,4,3,2,1]

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(n):
    num = str(n)
    answer = []
    for i in range(len(num)):
        answer.append(int(num[i]))
    answer = answer[::-1]
    return answer

# %%
solution(12345)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# 2) gpt가 쓴 답

# %% [markdown]
# (1) 완전 개선

# %%
def solution(n):
    # n을 문자열로 변환한 후, 이를 뒤집고 각 문자를 다시 정수로 변환한 리스트를 반환
    return [int(i) for i in str(n)[::-1]]

# %%
n = 12345
print(solution(n))  # 출력: [5, 4, 3, 2, 1]
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# (2) 일부 개선

# %%
def solution(n):
    # 문자열로 변환 후 뒤집은 다음, 각 문자를 숫자로 변환한 리스트를 반환
    num = str(n)
    answer = [int(i) for i in num[::-1]]  # 문자열을 뒤집고 각 문자를 int로 변환
    return answer

# %% [markdown]
# 3) 다른 사람들이 쓴 답

# %%
def digit_reverse(n):
    return list(map(int, reversed(str(n))))

# %%
# def digit_reverse(n):
#    return list(map(int, reversed(str(n))))

# 1. str(n):

# 먼저, 숫자 n을 문자열로 변환합니다.
# 예를 들어, n = 12345일 경우, str(n)은 "12345"가 됩니다.

# 2. reversed(str(n)):

# 문자열 "12345"의 문자를 뒤집습니다.
# reversed() 함수는 시퀀스(문자열, 리스트 등)를 역순으로 돌려주는 함수로, 결과는 "54321"이 됩니다.
# 중요한 점은 reversed()는 문자열 자체를 변경하는 것이 아니라, 역순으로 탐색하는 이터레이터를 반환한다는 점입니다.

# 3. map(int, reversed(str(n))):

# map() 함수는 두 개의 인자를 받는데, 첫 번째 인자 int는 적용할 함수, 두 번째 인자는 반복 가능한 객체(여기서는 reversed(str(n)))입니다.
# 이 부분은 뒤집힌 문자열 "54321"의 각 문자를 int로 변환합니다.
# 즉, map(int, reversed(str(n)))은 [5, 4, 3, 2, 1]이라는 이터레이터를 반환합니다.

# 4. list(map(int, reversed(str(n)))):

# 마지막으로 map() 함수로 변환된 이터레이터를 list() 함수로 리스트로 변환합니다.
# 최종 결과는 [5, 4, 3, 2, 1]이라는 리스트가 됩니다.
# 전체 동작 요약:
# 숫자를 문자열로 변환한 후 뒤집음.
# 뒤집힌 문자열의 각 문자를 숫자로 변환.
# 이를 리스트로 변환하여 반환.

# %% [markdown]
# 14. 정수 내림차순으로 배치하기(241101)

# %%
# 문제 설명
# 함수 solution은 정수 n을 매개변수로 입력받습니다.
# n의 각 자릿수를 큰것부터 작은 순으로 정렬한 새로운 정수를 리턴해주세요.
# 예를들어 n이 118372면 873211을 리턴하면 됩니다.

# 제한 조건
# n은 1이상 8000000000 이하인 자연수입니다.

# 입출력 예
# n	return
# 118372	873211

# %% [markdown]
# 1) 내가 쓴답

# %%
def solution(n):
    num = []
    answer = ''
    a = list(str(n))
    a.sort()
    for i in range(len(str(n))):
        num.append(a[i])
        answer = num[i] + answer
    return int(answer)

# %%
solution(12345)
# Out:
# 54321

# %% [markdown]
# 2) 다른 사람이 쓴 답

# %%
def solution(n):
    ls = list(str(n))
    ls.sort(reverse = True)
    return int("".join(ls))

# %%
solution(12345)
# Out:
# 54321

# %% [markdown]
# 3) gpt가 쓴 답

# %%
def solution(n):
    return int(''.join(sorted(str(n), reverse=True)))

# %%
solution(12345)
# Out:
# 54321

# %%
# 변경 사항 설명
# str(n)으로 숫자를 문자열로 변환한 후, sorted() 함수로 내림차순 정렬을 수행합니다.
# ''.join()으로 정렬된 문자열을 하나의 문자열로 합칩니다.
# int()로 다시 정수형으로 변환해 반환합니다.

# %% [markdown]
#  15. 정수 제곱근 판별(241104) - 오답

# %%
#  문제 설명
# 임의의 양의 정수 n에 대해, n이 어떤 양의 정수 x의 제곱인지 아닌지 판단하려 합니다.
# n이 양의 정수 x의 제곱이라면 x+1의 제곱을 리턴하고, n이 양의 정수 x의 제곱이 아니라면 -1을 리턴하는 함수를 완성하세요.

# 제한 사항
# n은 1이상, 50000000000000 이하인 양의 정수입니다.

# 입출력 예
# n	return
# 121	144
# 3	-1

# 입출력 예 설명

# 입출력 예#1
# 121은 양의 정수 11의 제곱이므로, (11+1)를 제곱한 144를 리턴합니다.

# 입출력 예#2
# 3은 양의 정수의 제곱이 아니므로, -1을 리턴합니다.

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(n):
    a = n**0.5
    if isinstance(a, int) == True:
        answer = (a+1)**2
    elif isinstance(a, int) == False:
        answer = -1
    return answer

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(n):
    a = n ** 0.5
    if a == int(a):  # 제곱근이 정수인지 확인
        answer = int((a + 1) ** 2)
    else:
        answer = -1
    return answer

# %% [markdown]
# 3) 다른 사람들이 쓴 답

# %%
def nextSqure(n):
    sqrt = n ** (1/2)

    if sqrt % 1 == 0:
        return (sqrt + 1) ** 2
    return 'no'

# %% [markdown]
# 16. 하샤드 수(241105)

# %%
# 문제 설명
# 양의 정수 x가 하샤드 수이려면 x의 자릿수의 합으로 x가 나누어져야 합니다.
# 예를 들어 18의 자릿수 합은 1+8=9이고,
# 18은 9로 나누어 떨어지므로 18은 하샤드 수입니다.
# 자연수 x를 입력받아 x가 하샤드 수인지 아닌지 검사하는 함수, solution을 완성해주세요.

# 제한 조건
# x는 1 이상, 10000 이하인 정수입니다.
# 입출력 예
# x	return
# 10	true
# 12	true
# 11	false
# 13	false
# 입출력 예 설명
# 입출력 예 #1
# 10의 모든 자릿수의 합은 1입니다. 10은 1로 나누어 떨어지므로 10은 하샤드 수입니다.

# 입출력 예 #2
# 12의 모든 자릿수의 합은 3입니다.
# 12는 3으로 나누어 떨어지므로 12는 하샤드 수입니다.

# 입출력 예 #3
# 11의 모든 자릿수의 합은 2입니다.
# 11은 2로 나누어 떨어지지 않으므로 11는 하샤드 수가 아닙니다.

# 입출력 예 #4
# 13의 모든 자릿수의 합은 4입니다.
# 13은 4로 나누어 떨어지지 않으므로 13은 하샤드 수가 아닙니다.

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(x):
    a=0
    for i in range(len(str(x))):
        a += int(str(x)[i])
    if x%a == 0:
        answer = True
    elif x%a != 0:
        answer = False
    return answer

# %%
solution(18)
# Out:
# True

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(x):
    a = sum(int(digit) for digit in str(x))  # 자릿수 합 계산
    return x % a == 0  # 조건을 바로 반환

# %% [markdown]
# 3) 다른 사람들이 쓴 답

# %%
def Harshad(n):
    return n%sum(int(x) for x in str(n)) == 0

# 아래는 테스트로 출력해 보기 위한 코드입니다.
print(Harshad(18))
# Out:
# True

# %% [markdown]
# 17. 나누어 떨어지는 숫자 배열(241111)

# %%
# 문제 설명
# array의 각 element 중 divisor로 나누어 떨어지는 값을
# 오름차순으로 정렬한 배열을 반환하는 함수, solution을 작성해주세요.
# divisor로 나누어 떨어지는 element가 하나도 없다면 배열에 -1을 담아 반환하세요.

# 제한사항
# arr은 자연수를 담은 배열입니다.
# 정수 i, j에 대해 i ≠ j 이면 arr[i] ≠ arr[j] 입니다.
# divisor는 자연수입니다.
# array는 길이 1 이상인 배열입니다.

# 입출력 예
# arr	divisor	return
# [5, 9, 7, 10]	5	[5, 10]
# [2, 36, 1, 3]	1	[1, 2, 3, 36]
# [3,2,6]	10	[-1]

# 입출력 예 설명

# 입출력 예#1
# arr의 원소 중 5로 나누어 떨어지는 원소는 5와 10입니다.
# 따라서 [5, 10]을 리턴합니다.

# 입출력 예#2
# arr의 모든 원소는 1으로 나누어 떨어집니다.
# 원소를 오름차순으로 정렬해 [1, 2, 3, 36]을 리턴합니다.

# 입출력 예#3
# 3, 2, 6은 10으로 나누어 떨어지지 않습니다.
# 나누어 떨어지는 원소가 없으므로 [-1]을 리턴합니다.

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(arr, divisor):
    answer = []  # 나누어 떨어지는 값을 저장할 리스트

    for i in arr:
        if i % divisor == 0:
            answer.append(i)

    if not answer:  # 나누어 떨어지는 값이 없으면
        return [-1]

    # 나누어 떨어지는 값들을 문자열로 변환하여 내림차순 정렬 후 결합
    sorted_answer = ''.join(sorted(map(str, answer), reverse=True))

    return int(sorted_answer)

# %%
solution([2, 36, 1, 3], 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 solution([2, 36, 1, 3], 1)
#
# Input In [18], in solution(arr, divisor)
#       8 if not answer:  # 나누어 떨어지는 값이 없으면
#       9     answer = [-1]
# ---> 11 return int(''.join(sorted(answer, reverse=True)))
#
# TypeError: sequence item 0: expected str instance, int found

# %% [markdown]
# 2) gpt로 개선한 답

# %%
def solution(arr, divisor):
    answer = [i for i in arr if i % divisor == 0]

    if not answer:  # 나누어 떨어지는 값이 없으면
        return [-1]

    return sorted(answer)  # 숫자 자체를 오름차순으로 정렬

# %% [markdown]
# 3) 다른 사람들이 쓴 답

# %%
def solution(arr, divisor): return sorted([n for n in arr if n%divisor == 0]) or [-1]

# %% [markdown]
# 4) gpt가 쓴 답

# %%
def solution(arr, divisor):
    answer = [x for x in arr if x % divisor == 0]  # divisor로 나누어 떨어지는 값만 리스트에 포함
    if not answer:  # 나누어 떨어지는 값이 없으면
        return [-1]
    return sorted(answer)  # 오름차순으로 정렬하여 반환

# %% [markdown]
# 18. 서울에서 김서방 찾기(241112)

# %%
# 문제 설명

# String형 배열 seoul의 element중 "Kim"의 위치 x를 찾아,
# "김서방은 x에 있다"는 String을 반환하는 함수,
# solution을 완성하세요.
# seoul에 "Kim"은 오직 한 번만 나타나며 잘못된 값이 입력되는 경우는 없습니다.

# 제한 사항
# seoul은 길이 1 이상, 1000 이하인 배열입니다.
# seoul의 원소는 길이 1 이상, 20 이하인 문자열입니다.
# "Kim"은 반드시 seoul 안에 포함되어 있습니다.

# 입출력 예
# seoul	return
# ["Jane", "Kim"]	"김서방은 1에 있다"

# %% [markdown]
# 1) 내가 쓴 답

# %%
seoul = ["Jane", "Kim"]

# %%
def solution(seoul):
    for i in range(len(list(seoul))):
        if list(seoul)[i] == "Kim":
            answer = f'김서방은 {i}에 있다'
    return answer

# %%
solution(seoul)
# Out:
# '김서방은 1에 있다'

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(seoul):
    index = seoul.index("Kim")
    return f'김서방은 {index}에 있다'

# %% [markdown]
# 2) 다른사람의 답

# %%
def findKim(seoul):
    # 함수를 완성하세요

    return "김서방은 {}에 있다".format(seoul.index('Kim'))


# 실행을 위한 테스트코드입니다.
print(findKim(["Queen", "Tod", "Kim"]))
# Out:
# 김서방은 2에 있다

# %% [markdown]
#  19. 콜라츠 추측(241113)

# %%
# 문제 설명

# 1937년 Collatz란 사람에 의해 제기된 이 추측은,
# 주어진 수가 1이 될 때까지 다음 작업을 반복하면,
# 모든 수를 1로 만들 수 있다는 추측입니다. 작업은 다음과 같습니다.

# 1-1. 입력된 수가 짝수라면 2로 나눕니다.
# 1-2. 입력된 수가 홀수라면 3을 곱하고 1을 더합니다.
# 2. 결과로 나온 수에 같은 작업을 1이 될 때까지 반복합니다.
# 예를 들어, 주어진 수가 6이라면 6 → 3 → 10 → 5 → 16 → 8 → 4 → 2 → 1 이 되어
# 총 8번 만에 1이 됩니다.
# 위 작업을 몇 번이나 반복해야 하는지 반환하는 함수, solution을 완성해 주세요.
# 단, 주어진 수가 1인 경우에는 0을,
# 작업을 500번 반복할 때까지 1이 되지 않는다면 –1을 반환해 주세요.

# 제한 사항
# 입력된 수, num은 1 이상 8,000,000 미만인 정수입니다.
# 입출력 예
# n	result
# 6	8
# 16	4
# 626331	-1
# 입출력 예 설명
# 입출력 예 #1
# 문제의 설명과 같습니다.

# 입출력 예 #2
# 16 → 8 → 4 → 2 → 1 이 되어 총 4번 만에 1이 됩니다.

# 입출력 예 #3
# 626331은 500번을 시도해도 1이 되지 못하므로 -1을 리턴해야 합니다.

# ※ 공지 - 2022년 6월 10일 다음과 같이 지문이 일부 수정되었습니다.

# 주어진 수가 1인 경우에 대한 조건 추가

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(num):
    a = 0
    n = 0
    if int(num) != 1:
        if int(num) % 2 == 0:
            n = (int(num))/2
        elif int(num) % 2 != 0:
            n = (int(num)*3)+1
        a=a+1
        while True:
            a=a+1
            if a <= 500:
                if n % 2 == 0:
                    n = n/2
                elif n % 2 != 0:
                    n = (n*3)+1
                if n == 1:
                    break
            else:
                a = -1
                break
        answer = a
    else:
        answer = 0
    return answer

# %%
solution(626331)
# Out:
# -1

# %% [markdown]
# 2) gpt가 쓴 답

# %%
def solution(num):
    num = int(num)  # num을 정수형으로 변환하여 안정성 확보

    if num == 1:
        return 0

    count = 0  # 반복 횟수 초기화

    while num != 1:
        if count >= 500:
            return -1
        num = num // 2 if num % 2 == 0 else num * 3 + 1
        count += 1

    return count

# %%
solution(6)
# Out:
# 8

# %% [markdown]
# 20. 음양더하기 - 월간 코드 챌린지 시즌2(241114)

# %%
#  문제 설명
# 어떤 정수들이 있습니다. 이 정수들의 절댓값을 차례대로 담은 정수 배열
# absolutes와 이 정수들의 부호를 차례대로 담은 불리언 배열 signs가
# 매개변수로 주어집니다. 실제 정수들의 합을 구하여 return 하도록
# solution 함수를 완성해주세요.

# 제한사항
# absolutes의 길이는 1 이상 1,000 이하입니다.
# absolutes의 모든 수는 각각 1 이상 1,000 이하입니다.
# signs의 길이는 absolutes의 길이와 같습니다.
# signs[i] 가 참이면 absolutes[i] 의 실제 정수가 양수임을,
# 그렇지 않으면 음수임을 의미합니다.


# 입출력 예
# absolutes	signs	result
# [4,7,12]	[true,false,true]	9
# [1,2,3]	[false,false,true]	0


# 입출력 예 설명

# 입출력 예 #1
# signs가 [true,false,true] 이므로, 실제 수들의 값은 각각 4, -7, 12입니다.
# 따라서 세 수의 합인 9를 return 해야 합니다.

# 입출력 예 #2
# signs가 [false,false,true] 이므로, 실제 수들의 값은 각각 -1, -2, 3입니다.
# 따라서 세 수의 합인 0을 return 해야 합니다.

# %% [markdown]
# 1) 내가 쓴 답

# %%
def solution(absolutes, signs):
    for i in range(len(absolutes)):
        if signs[i] == True:
            absolutes[i] = absolutes[i]
        else:
            absolutes[i] = -absolutes[i]
    answer = sum(absolutes)
    return answer

# %%
absolutes = [4,7,12]

# %%
signs = [True,False,True]

# %%
solution(absolutes, signs)
# Out:
# 9

# %% [markdown]
# 2) gpt가 개선한 답

# %%
def solution(absolutes, signs):
    answer = sum(absolutes[i] if signs[i] else -absolutes[i] for i in range(len(absolutes)))
    return answer

# %% [markdown]
# 3) 다른 사람들이 쓴 답

# %%
def solution(absolutes, signs):
    return sum(absolutes if sign else -absolutes for absolutes, sign in zip(absolutes, signs))
